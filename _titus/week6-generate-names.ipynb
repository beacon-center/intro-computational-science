# %%
gender = ['m', 'f']
ages = list(range(14, 30))
jackets = ['red', 'blue', 'green', 'black', 'white']

# %%
names = """Addie Dehner
Catina Maggart
Lory Javier
Vernetta Kornfeld
Arielle Alpaugh
Wen Varela
Erna Giunta
Melanie Brenneman
Ahmad Oller
Exie Nantz
Yolonda Updegraff
Lorie Dibernardo
Maren Schaber
Shalon Tooker
Maria Warkentin
Shayla Say
Jeramy Ridgell
Bridgett Lenig
Jenniffer Gum
Darrin Montalbano
Debby Bracken
Trudi Edelstein
Chad Frahm
Calandra Vangilder
Lavina Bellone
Marielle Hertzog
Veronica Flaugher
Harold Redrick
Bettie Koziel
Garnet Kerman
Eliz Huertas
Nettie Minter
Lorean Farless
Georgette Ketner
Magdalene Spears
Mandy Burgio
Gita Veach
Dodie Bhakta
Christena Freed
Una Ohman
Kaye Thorn
Alix Camburn
Darby Waddle
Jeffie Spells
Susan Audia
Houston Parsley
Lenore Fritsche
Kristi Pizarro
Perla Adolph
Tyesha Seigel
Abe Hageman
Michel Hosey
Alden Mai
Leatha Cabral
Synthia Beauford
Sung Caul
Carolyne Schoen
Evia Marcinkowski
Iluminada Thorington
Toni Pita
Lawanda Lafortune
Ronald Nielson
Christie Bechtel
Jin Sterner
Alena Lasseter
Lora Twomey
Kasie Pantoja
Dorthy Faas
Magan Deibler
Loria Ochs
Delphine Smock
Farah Huey
Joye Konkel
Chaya Askey
Elfriede Halperin
Carlos Snipes
Keren Pettiford
Tawna Angeles
Romana Jacobson
Norma Harps
Kasi Viger
Russell Fore
Joetta Wanamaker
Deloras Collins
Jacquelynn Shores
Jolynn Solem
Tierra Levier
Berry Chiesa
Vanesa Majeed
Lauralee Maurin
Joycelyn Silvester
Delinda Burtch
Ezekiel Wesely
Dung Kirsh
Chang Lando
Latarsha Martine
Britany Kalish
Eloise Wildes
Marcy Janowski
Cayla Waye
""".splitlines()

# %%
import random
random.shuffle(names)

# %%
fp = open('/mnt/out.csv', 'w')
import csv
w = csv.writer(fp, delimiter='\t')

for n in names:
    mf = random.choice(gender)
    jacket = random.choice(jackets)
    age = random.choice(ages)
    w.writerow([n, mf, jacket, age])

fp.close()

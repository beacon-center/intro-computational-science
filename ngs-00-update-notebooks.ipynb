# %%
cd /usr/local/notebooks
# Out:
# /usr/local/notebooks

# %%
ls
# Out:
# lib/  ngs-00-update-notebooks.ipynb  ngs-10-blast.ipynb  README.txt

# %%
# !git checkout -f master
# Out:
# Already on 'master'

# %%
# !git pull origin master
# Out:
# From git://github.com/ctb/ngs-notebooks * branch            master     -> FETCH_HEAD
# Already up-to-date.
